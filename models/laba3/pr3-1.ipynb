# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://github.com/koroteevmv/ML_course/raw/refs/heads/main/ML3.1%20polynomial%20features/data/gen_regression.csv",
                   index_col=0)
data.head()
# Out:
#            x             y
# 0  96.597780  97761.592016
# 1  48.002892  27613.989207
# 2  47.939756  29410.187753
# 3  47.809026  15789.597531
# 4  69.784427  20953.383453

# %%
X = pd.DataFrame(data.x)
y = data.y

# %%
X.shape , y.shape
# Out:
# ((100, 1), (100,))

# %%
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression().fit(X, y)

# %%
plt.scatter(X, y)

xx = np.arange(X.x.min(axis=0), X.x.max(axis=0))
yy = linear.predict(pd.DataFrame(xx))
plt.plot(xx, yy, color='red')
# Out:
# C:\Users\kukuw\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
linear.score(X, y)
# Out:
# 0.37467360318911636

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
transformer = PolynomialFeatures(degree=2, include_bias=False)

# %%
transformer.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
X_2 = transformer.transform(X)

# %%
X_2.shape
# Out:
# (100, 2)

# %%
X_2[:5]
# Out:
# array([[  96.59778046, 9331.13118921],
#        [  48.00289214, 2304.27765375],
#        [  47.93975578, 2298.22018452],
#        [  47.80902582, 2285.70294968],
#        [  69.78442711, 4869.86626705]])

# %%
X[:5]
# Out:
#            x
# 0  96.597780
# 1  48.002892
# 2  47.939756
# 3  47.809026
# 4  69.784427

# %%
poly_2d = LinearRegression().fit(X_2, y)

# %%
poly_2d.score(X_2, y)
# Out:
# 0.7359753787024843

# %%
plt.scatter(X, y)

xx = np.arange(X.x.min(axis=0), X.x.max(axis=0))
xx_2d = transformer.transform(pd.DataFrame(xx))
yy = poly_2d.predict(xx_2d)
plt.plot(xx, yy, color='red')
# Out:
# C:\Users\kukuw\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
transformer_2 = PolynomialFeatures(degree=10)
transformer_2.fit(X)
X_3 = transformer_2.transform(X)
poly_3d = LinearRegression().fit(X_3, y)
poly_3d.score(X_3, y)
# Out:
# 0.9222468251462038
